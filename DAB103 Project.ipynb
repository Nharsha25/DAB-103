# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings                                                                 # Ignore warning related to pandas_profiling
warnings.filterwarnings('ignore')

# %%
deliveries = pd.read_csv(r"F:\St. Clair\COURSES\DAB 103\Proj\dataset\deliveries.csv")
matches = pd.read_csv(r"F:\St. Clair\COURSES\DAB 103\Proj\dataset\matches.csv")
avgstrike = pd.read_csv(r"F:\St. Clair\COURSES\DAB 103\Proj\dataset\avgstrike.csv")
players = pd.read_csv(r"F:\St. Clair\COURSES\DAB 103\Proj\dataset\Players.csv")
teams = pd.read_csv(r"F:\St. Clair\COURSES\DAB 103\Proj\dataset\teams.csv")
teamwisewinnigs = pd.read_csv(r"F:\St. Clair\COURSES\DAB 103\Proj\dataset\teamwise.csv")

# %%
matches.describe()
# Out:
#                  id  dl_applied  win_by_runs  win_by_wickets
# count    756.000000  756.000000   756.000000      756.000000
# mean    1792.178571    0.025132    13.283069        3.350529
# std     3464.478148    0.156630    23.471144        3.387963
# min        1.000000    0.000000     0.000000        0.000000
# 25%      189.750000    0.000000     0.000000        0.000000
# 50%      378.500000    0.000000     0.000000        4.000000
# 75%      567.250000    0.000000    19.000000        6.000000
# max    11415.000000    1.000000   146.000000       10.000000

# %%
matches.isnull().sum()
# Out:
# id                   0
# Season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
print(deliveries.head())
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
deliveries.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    170244
# dismissal_kind      170244
# fielder             172630
# dtype: int64

# %%
players.head()
# Out:
#       Player_Name        DOB Batting_Hand         Bowling_Skill Country
# 0  A Ashish Reddy  24-Feb-91   Right_Hand      Right-arm medium   India
# 1      A Chandila   5-Dec-83   Right_Hand    Right-arm offbreak   India
# 2        A Chopra  19-Sep-77   Right_Hand    Right-arm offbreak   India
# 3     A Choudhary        NaN   Right_hand  Left-arm fast-medium     NaN
# 4     A Dananjaya        NaN   Right_Hand    Right-arm offbreak     NaN

# %%
players.tail()
# Out:
#       Player_Name        DOB Batting_Hand           Bowling_Skill   Country
# 561   Younis Khan  29-Nov-77   Right_Hand        Right-arm medium  Pakistan
# 562     YS Chahal  23-Jul-90   Right_Hand         Legbreak googly     India
# 563  Yuvraj Singh  12-Dec-81    Left_Hand  Slow left-arm orthodox     India
# 564   YV Takawale   5-Nov-84   Right_Hand                     NaN     India
# 565        Z Khan   7-Oct-78   Right_Hand    Left-arm fast-medium     India

# %%
players.isnull().sum()
# Out:
# Player_Name       0
# DOB              95
# Batting_Hand      3
# Bowling_Skill    64
# Country          95
# dtype: int64

# %%
print(players.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 566 entries, 0 to 565
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Player_Name    566 non-null    object
#  1   DOB            471 non-null    object
#  2   Batting_Hand   563 non-null    object
#  3   Bowling_Skill  502 non-null    object
#  4   Country        471 non-null    object
# dtypes: object(5)
# memory usage: 22.2+ KB
# None

# %%
print(matches.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   Season           756 non-null    object
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
matches.isnull().sum()
# Out:
# id                   0
# Season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
matches.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
deliveries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
#Filling in the missing values of city column
#First let's find the venues corresponding to which the values of city are empty

matches[matches.city.isnull()][['city','venue']]
# Out:
#     city                                venue
# 461  NaN  Dubai International Cricket Stadium
# 462  NaN  Dubai International Cricket Stadium
# 466  NaN  Dubai International Cricket Stadium
# 468  NaN  Dubai International Cricket Stadium
# 469  NaN  Dubai International Cricket Stadium
# 474  NaN  Dubai International Cricket Stadium
# 476  NaN  Dubai International Cricket Stadium

# %%
#umpire1 and umpire2 columns have one missing value each

matches[(matches.umpire1.isnull()) | (matches.umpire2.isnull())]
# Out:
#         id    Season           city        date                        team1  \
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
#
#                 team2                  toss_winner toss_decision  result  \
# 4    Delhi Daredevils  Royal Challengers Bangalore           bat  normal
# 753    Delhi Capitals               Delhi Capitals         field  normal
#
#      dl_applied                       winner  win_by_runs  win_by_wickets  \
# 4             0  Royal Challengers Bangalore           15               0
# 753           0               Delhi Capitals            0               2
#
#     player_of_match                  venue umpire1 umpire2 umpire3
# 4         KM Jadhav  M Chinnaswamy Stadium     NaN     NaN     NaN
# 753         RR Pant       ACA-VDCA Stadium     NaN     NaN     NaN

# %%
matches.city = matches.city.fillna('Dubai')

# %%
#umpire3 column has close to 92% missing values. hence dropping that column

matches = matches.drop('umpire3', axis = 1)

# %%
so = deliveries['batsman_runs']

plt.hist(so,edgecolor="k")

plt.xlabel('Over')
plt.ylabel('No of runs ')
plt.title('Average number of runs in an over')
print(plt.show())
# Out:
# None

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='Season',
              hue='toss_decision',
              data=matches,
              order = matches['Season'].value_counts().index.sort_values(),
              palette='deep')
plt.xlabel('Season',fontsize=12)
plt.ylabel('Count',fontsize=12)
plt.title('Decision to field or bat in each IPL season', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Decision to field or bat in each IPL season')

# %%
matches = pd.read_csv(r"F:\St. Clair\COURSES\DAB 103\Proj\dataset\matches.csv")
deliveries = pd.read_csv(r"F:\St. Clair\COURSES\DAB 103\Proj\dataset\deliveries.csv")


merge_df = pd.merge(deliveries,matches, left_on='match_id', right_on ='id')

consistent_batsman = merge_df[merge_df.batsman.isin(['SK Raina', 'V Kohli','RG Sharma','G Gambhir',
                                            'RV Uthappa', 'S Dhawan','CH Gayle', 'MS Dhoni',
                                            'DA Warner', 'AB de Villiers'])][['batsman','Season','total_runs']]

consistent_batsman.groupby(['Season','batsman'])['total_runs'].sum().unstack().plot(kind = 'box', figsize = (15,8))
plt.title("Batsman with Highest Strike Rate", fontsize = 20, fontweight = 'bold')
plt.xlabel("Batsmen", size = 25)
plt.ylabel("Total Runs Scored each season", size = 25)
plt.xticks(size = 15)
plt.yticks(size = 15)
# Out:
# (array([-200.,    0.,  200.,  400.,  600.,  800., 1000., 1200.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
wides = pd.DataFrame(merge_df.groupby('bowler')['wide_runs'].sum())
noballs = pd.DataFrame(merge_df.groupby('bowler')['noball_runs'].sum())
season = pd.DataFrame(merge_df.groupby('bowler')['Season'].nunique())

extras_by_bowlers = pd.DataFrame({'wides':wides['wide_runs'],'no_balls':noballs['noball_runs']})
extras_by_bowlers.reset_index(inplace = True)
extras_by_bowlers['total_extras'] = extras_by_bowlers['wides'] + extras_by_bowlers['no_balls']
most_extras = extras_by_bowlers.sort_values(by='total_extras', ascending = False).head(15)

plt.figure(figsize = (15,6))
sns.barplot(x = 'bowler', y = 'wides', data = most_extras)
sns.barplot(x = 'bowler', y = 'no_balls', data = most_extras)
plt.title("Extras given by Bowlers",fontsize= 25, fontweight = 'bold')
plt.xlabel("Player", size = 25)
plt.ylabel("Wides and No balls", size = 25)
plt.xticks(size = 10)
plt.yticks(size = 14)
# Out:
# (array([  0.,  20.,  40.,  60.,  80., 100., 120., 140., 160.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# Plot to visualise the no. of matches where D/L method was applied season wise
year=matches.query('dl_applied==1')['Season']
fig, ax=plt.subplots()
ax.set_ylim([0,5])
ax.set_title('No. of matches where D/L method was applied, season wise\n')
sns.countplot(x=year, data=matches)
plt.xlabel('\nSeason')
plt.ylabel('No. of matches\n')
plt.show()

# %%
matches.toss_decision.value_counts()/len(matches)*100

matches['toss_decision'].value_counts().plot(kind='pie', fontsize=14, autopct='%3.1f%%', 
                                               figsize=(10,7), shadow=True, startangle=135, legend=True, cmap='Oranges')

plt.ylabel('Toss Decision')
plt.title('Decision taken by captains after winning tosses')
# Out:
# Text(0.5, 1.0, 'Decision taken by captains after winning tosses')

# %%
new_matches = matches[matches['result'] == 'normal']   #taking all those matches where result is normal and creating a new dataframe
new_matches['win_batting_first'] = np.where((new_matches.win_by_runs > 0), 'Yes', 'No')
new_matches.win_batting_first.value_counts()/len(new_matches)*100

plt.figure(figsize=(10,5))
sns.countplot('win_batting_first', data = new_matches)
plt.title("Win batting first or second?",fontsize=18,fontweight="bold")
plt.ylabel("Frequency", size = 25)
plt.xlabel("Win by batting first or second", size = 25)
plt.xticks(size = 15)
plt.yticks(size = 15)
# Out:
# (array([  0.,  50., 100., 150., 200., 250., 300., 350., 400., 450.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# No. of matches played in different stadiums
sns.countplot(y='venue', data=matches)
plt.title('No. of matches played in different stadiums\n')
plt.xlabel('\nNo. of matches played')
plt.ylabel('Stadiums\n')
plt.show()

# %%
so = deliveries['batsman_runs'].transform ([np.sqrt,np.exp])

so.hist(bins=20,layout =(2,1),edgecolor="k", figsize=(10,10))

plt.xlabel('Over')
plt.ylabel('No of runs ')

plt.title('Average number of runs in an over')

print(plt.show())
# Out:
# None

# %%
plt.figure(figsize = (18, 12))



corr = deliveries.corr()

mask = np.triu(np.ones_like(corr, dtype = bool))



sns.heatmap(data = corr, mask = mask, annot = True, fmt = '.2g', linewidth = 1)

plt.show()

# %%
Striking Rate

# %%
sr = avgstrike['strikerate']

plt.hist(sr,edgecolor='black',color = "skyblue")

plt.xlabel('Strike Rate')
plt.ylabel('count')
plt.axvline(sr.mean(), color='red', linewidth=1)
plt.axvline(sr.median(), color='green', linewidth=1)
plt.title("Distribution of the strike rate")
print(plt.show())
# Out:
# None

# %%
plt.figure(figsize=(15,5))
sns.countplot('Season', data = matches)
plt.title("Number of matches played each season",fontsize=18,fontweight="bold")
plt.ylabel("Count", size = 25)
plt.xlabel("Season", size = 25)
plt.xticks(size = 15)
plt.yticks(size = 15)
# Out:
# (array([ 0., 10., 20., 30., 40., 50., 60., 70., 80.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
x = teamwisewinnigs['team']
#print(x)
y=teamwisewinnigs['away_wins']
#print (y)
sns.barplot(y,x)
plt.ylabel('Team Names')
plt.xlabel(' Home away Wins ')
plt.title('Teams and their victory in outside the Homegrounds.')
print(plt.show())
# Out:
# None

# %%
x= teamwisewinnigs['home_wins']
y = teamwisewinnigs['team']
z  = teamwisewinnigs['home_win_percentage']
plt.scatter(x,y)
plt.xlabel('  Home win percentage')
plt.ylabel('Team Names')
plt.title("Teams and thier winning percentage in Homeground")
print(plt.show( ))
# Out:
# None

# %%
matches.toss_decision.value_counts()/len(matches)*100

# %%
matches['toss_decision'].value_counts().plot(kind='pie', fontsize=14, autopct='%3.1f%%',
                                               figsize=(10,7), shadow=True, startangle=135, legend=True, cmap='Oranges')

plt.ylabel('Toss Decision')
plt.title('Decision taken by captains after winning tosses')
# Out:
# Text(0.5, 1.0, 'Decision taken by captains after winning tosses')

# %%
## Probability that the toss winner will win the match
z=matches[matches['toss_winner']==matches['winner']]
slices=[len(z),(len(matches)-len(z))]
labels=['Yes','No']
plt.pie(slices,labels=labels,autopct='%1.2f%%')
fig = plt.gcf()
plt.show()

# %%
Univariate Analysis

# %%
Which batsman has been most consistent among top 10 run getters?

# %%
merge_df.groupby(['batting_team','Season'])['batsman_runs'].sum().unstack().plot(kind = 'bar',stacked = True ,
                                                                                figsize = (25,10))
plt.title("Runs over the years for each team",fontsize= 35, fontweight = 'bold')
plt.xlabel("Teams", size = 30)
plt.ylabel("Total Runs Scored", size = 30)
plt.xticks(size = 25)
plt.yticks(size = 25)
# Out:
# (array([    0.,  5000., 10000., 15000., 20000., 25000., 30000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# Plot to visualise the top 10 players based on the no. of MOM awards won
mom=matches['player_of_match'].value_counts()[:10]

fig, ax=plt.subplots()
ax.set_ylim([0,28])
ax.set_title('Top 10 players based on no. of MOM awards won\n')
sns.barplot( y=mom,x=mom.index, orient='v')
plt.ylabel('No. of MOM awards won\n')
plt.xlabel('\nPlayers')
plt.show()

# %%
merge_df.groupby('Season')['batsman_runs'].sum().plot(kind = 'line', linewidth = 3, figsize =(15,5),
                                                                                             color = 'red')
plt.title("Runs over the years",fontsize= 25, fontweight = 'bold')
plt.xlabel("Season", size = 25)
plt.ylabel("Total Runs Scored", size = 25)
plt.xticks(size = 12)
plt.yticks(size = 12)
# Out:
# (array([15000., 16000., 17000., 18000., 19000., 20000., 21000., 22000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
#--> The graph will show the decision of fielding or batting if a team wins the toss. 
sns.countplot(y='Season',hue='toss_decision',data=matches)
plt.xlabel('No of Tosses')
plt.show()

# %%
#--> The graph shows the team that won the most tosses
u=matches['toss_winner'].value_counts().plot.bar()
for l in u.patches:
    u.annotate(format(l.get_height()), (l.get_x()+0.15, l.get_height()+1))
plt.show()

# %%
#--> The graph shows the team that won the most number of matches
u=pd.concat([matches['team1'],matches['team2']])
matches_played_byteams=u.value_counts().reset_index()
matches_played_byteams.columns=['Team','Total Matches']
matches_played_byteams['wins']=matches['winner'].value_counts().reset_index()['winner']
matches_played_byteams.set_index('Team',inplace=True)
matches_played_byteams.plot.bar()
plt.ylable('No of Matches')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-bbc3d228a2cf> in <module>
#       6 matches_played_byteams.set_index('Team',inplace=True)
#       7 matches_played_byteams.plot.bar()
# ----> 8 plt.ylable('No of Matches')
#       9 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'ylable'
